# %%
from __future__ import division
import pylab as pl
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
import math
import seaborn as sns
import os

# %%
data = pd.read_csv('./data/t1_from_master.csv')
print(data.columns)
data["Trim Effeciency"] = data["Base - TP TRIM"]/(data["Base - TP TRIM"] + data["Base - FP TRIM"])
data['total_corrections']=data['Base - TP']+ data['Base - FP']
data = data[(data['Kmer Size'] >19)]
data.head()
# Out:
# Index(['Unnamed: 0', 'EC Filename', 'Wrapper Name', 'Kmer Size', 'Read - TP',
#        'Read - TN', 'Read - FN', 'Read - FN WRONG', 'Read - FP',
#        'Read - FP INDEL', 'Total Trimmed Reads', 'Total Reads', 'Base - TP',
#        'Base - TN', 'Base - FN', 'Base - FN WRONG', 'Base - FP',
#        'Base - FP INDEL', 'Base - FP TRIM', 'Base - TP TRIM', 'Total Bases',
#        'Tool', 'Coverage', 'Length', 'Base Sensitivity', 'Base Precision',
#        'Base Gain', 'Base Accuracy', 'Dataset', 'Trim Percent',
#        'Trim Effeciency'],
#       dtype='object')
#     Unnamed: 0                                     EC Filename Wrapper Name  \
# 16          60  bfc_t1_wgsim_rl__cov_1.1_20.corrected.fastq.gz   run.bfc.sh
# 17          63  bfc_t1_wgsim_rl__cov_1.1_21.corrected.fastq.gz   run.bfc.sh
# 19          68  bfc_t1_wgsim_rl__cov_2.1_20.corrected.fastq.gz   run.bfc.sh
# 22          76  bfc_t1_wgsim_rl__cov_4.1_20.corrected.fastq.gz   run.bfc.sh
# 23          78  bfc_t1_wgsim_rl__cov_8.1_20.corrected.fastq.gz   run.bfc.sh
#
#     Kmer Size  Read - TP  Read - TN  Read - FN  Read - FN WRONG  Read - FP  \
# 16         20        129      25409      16924               14       4224
# 17         21        134      25446      16905               10       4205
# 19         20        188      25226      16543               15       4728
# 22         20        494      24960      15885               22       5339
# 23         20       1287      24638      14837               24       5914
#
#     Read - FP INDEL        ...          Coverage  Length  Base Sensitivity  \
# 16                0        ...                 1     100          0.042079
# 17                0        ...                 1     100          0.043988
# 19                0        ...                 2     100          0.047670
# 22                0        ...                 4     100          0.070063
# 23                0        ...                 8     100          0.125136
#
#     Base Precision  Base Gain  Base Accuracy  Dataset  Trim Percent  \
# 16        0.086186  -0.404076       0.992932       T1           0.0
# 17        0.088904  -0.406803       0.992918       T1           0.0
# 19        0.089869  -0.435099       0.992840       T1           0.0
# 22        0.120256  -0.442489       0.992851       T1           0.0
# 23        0.196295  -0.387217       0.993135       T1           0.0
#
#     Trim Effeciency  total_corrections
# 16              NaN              11452
# 17              NaN              11608
# 19              NaN              12329
# 22              NaN              13438
# 23              NaN              14682
#
# [5 rows x 32 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
g=sns.set_style("white")
g=sns.set_context("talk")
g = sns.catplot(x="Kmer Size", y="Base Gain", kind="point",data = data[(data['Coverage'] ==1)]
, hue='Tool')
g.set(xlabel='Kmer size', ylabel='Gain')
g=sns.despine()
#plt.show(g)
plt.savefig("gain_cov1.png", bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
g=sns.set_style("white")
g=sns.set_context("talk")
g = sns.catplot(x="Kmer Size", y="Base Gain", kind="point",data = data[(data['Coverage'] ==2)]
, hue='Tool')
g.set(xlabel='Kmer size', ylabel='Gain')
g=sns.despine()
#plt.show(g)
plt.savefig("gain_cov2.png", bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
g=sns.set_style("white")
g=sns.set_context("talk")
g = sns.catplot(x="Kmer Size", y="Base Gain", kind="point",data = data[(data['Coverage'] ==4)]
, hue='Tool')
g.set(xlabel='Kmer size', ylabel='Gain')
g=sns.despine()
#plt.show(g)
plt.savefig("gain_cov4.png", bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
g=sns.set_style("white")
g=sns.set_context("talk")
g = sns.catplot(x="Kmer Size", y="Base Gain", kind="point",data = data[(data['Coverage'] ==8)]
, hue='Tool')
g.set(xlabel='Kmer size', ylabel='Gain')
g=sns.despine()
#plt.show(g)
plt.savefig("gain_cov8.png", bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
g=sns.set_style("white")
g=sns.set_context("talk")
g = sns.catplot(x="Kmer Size", y="Base Gain", kind="point",data = data[(data['Coverage'] ==16)]
, hue='Tool')
g.set(xlabel='Kmer size', ylabel='Gain')
g=sns.despine()
#plt.show(g)
plt.savefig("gain_cov16.png", bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
g=sns.set_style("white")
g=sns.set_context("talk")
g = sns.catplot(x="Kmer Size", y="total_corrections", kind="point",data = data[(data['Coverage'] ==1)]
, hue='Tool')
g.set(xlabel='Kmer size', ylabel='Total corrections')
g=sns.despine()
#plt.show(g)
plt.savefig("total_corrections_cov1.png", bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
g=sns.set_style("white")
g=sns.set_context("talk")
g = sns.catplot(x="Kmer Size", y="total_corrections", kind="point",data = data[(data['Coverage'] ==2)]
, hue='Tool')
g.set(xlabel='Kmer size', ylabel='Total corrections')
g=sns.despine()
#plt.show(g)
plt.savefig("total_corrections_cov2.png", bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
g=sns.set_style("white")
g=sns.set_context("talk")
g = sns.catplot(x="Kmer Size", y="total_corrections", kind="point",data = data[(data['Coverage'] ==32)]
, hue='Tool')
g.set(xlabel='Kmer size', ylabel='Total corrections')
g=sns.despine()
#plt.show(g)
plt.savefig("total_corrections_cov32.png", bbox_inches='tight')
