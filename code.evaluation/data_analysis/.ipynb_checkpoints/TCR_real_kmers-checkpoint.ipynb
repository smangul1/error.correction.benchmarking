# %%
from __future__ import division
import pylab as pl
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
import math
import seaborn as sns

# %%
data = pd.read_csv('./data/rsr_from_master.csv')
data.tail()
# Out:
#      Unnamed: 0                               EC Filename Wrapper Name  \
# 610         971  sga_SRR1543970_raw_16.corrected.fastq.gz   run.sga.sh
# 611         972  sga_SRR1543970_raw_24.corrected.fastq.gz   run.sga.sh
# 612         973  sga_SRR1543970_raw_19.corrected.fastq.gz   run.sga.sh
# 613         974  sga_SRR1543970_raw_26.corrected.fastq.gz   run.sga.sh
# 614         975  sga_SRR1543970_raw_28.corrected.fastq.gz   run.sga.sh
#
#      Kmer Size  Read - TP  Read - TN  Read - FN  Read - FN WRONG  Read - FP  \
# 610         16        292      52898       6225                4         53
# 611         24        380      52898       6122                5         64
# 612         19        317      52898       6189                4         62
# 613         26        400      52898       6102                3         66
# 614         28        422      52898       6076                3         70
#
#      Read - FP INDEL       ...         Tool  Coverage  Length  \
# 610                0       ...          Sga       NaN     100
# 611                3       ...          Sga       NaN     100
# 612                2       ...          Sga       NaN     100
# 613                3       ...          Sga       NaN     100
# 614                3       ...          Sga       NaN     100
#
#      Base Sensitivity  Base Precision  Base Gain  Base Accuracy  Dataset  \
# 610          0.094238        0.903040   0.084119       0.999245      RSR
# 611          0.126652        0.864675   0.106830       0.999263      RSR
# 612          0.108022        0.870678   0.091978       0.999251      RSR
# 613          0.128924        0.859348   0.107823       0.999264      RSR
# 614          0.136227        0.857451   0.113580       0.999269      RSR
#
#      Trim Percent  Trim Effeciency
# 610           0.0              NaN
# 611           0.0              NaN
# 612           0.0              NaN
# 613           0.0              NaN
# 614           0.0              NaN
#
# [5 rows x 31 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
g=sns.set_style("white")
g=sns.set_context("talk")
g = sns.catplot(x="Kmer Size", y="Base Gain", kind="point",data = data,hue='Tool')
, hue='Tool')
g.set(xlabel='Kmer size', ylabel='Gain')
g=sns.despine()
#plt.show(g)
plt.savefig("gain_TCR_real.png", bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
g=sns.set_style("white")
g=sns.set_context("talk")
g = sns.catplot(x="Kmer Size", y="Base Gain", kind="point",data = data[(data['Coverage'] ==32)]
, hue='Tool')
g.set(xlabel='Kmer size', ylabel='Gain')
g=sns.despine()
#plt.show(g)
plt.savefig("gain_cov4_TCRA.png", bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
g=sns.set_style("white")
g=sns.set_context("talk")
g = sns.catplot(x="Kmer Size", y="Base Gain", kind="point",data = data[(data['Coverage'] ==128)]
, hue='Tool')
g.set(xlabel='Kmer size', ylabel='Gain')
g=sns.despine()
#plt.show(g)
plt.savefig("gain_cov128_TCRA.png", bbox_inches='tight')
