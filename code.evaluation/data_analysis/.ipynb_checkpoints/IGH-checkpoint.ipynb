# %%
from __future__ import division
import pylab as pl
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
import math
import seaborn as sns
import os

# %%
data = pd.read_csv('./data/igh_from_master.csv')
print(data.columns)
data["Trim Effeciency"] = 100*data["Base - TP TRIM"]/(data["Base - TP TRIM"] + data["Base - FP TRIM"])

data['Trim Effeciency'] = data['Trim Effeciency'].fillna(0)
data= data[(data['Length'] =='100L')]
data['total_corrections']=data['Base - TP']+ data['Base - FP']
data.head()
# Out:
# Index(['Unnamed: 0', 'EC Filename', 'Wrapper Name', 'Kmer Size', 'Read - TP',
#        'Read - TN', 'Read - FN', 'Read - FN WRONG', 'Read - FP',
#        'Read - FP INDEL', 'Total Trimmed Reads', 'Total Reads', 'Base - TP',
#        'Base - TN', 'Base - FN', 'Base - FN WRONG', 'Base - FP',
#        'Base - FP INDEL', 'Base - FP TRIM', 'Base - TP TRIM', 'Total Bases',
#        'Tool', 'Coverage', 'Length', 'Base Sensitivity', 'Base Precision',
#        'Base Gain', 'Base Accuracy', 'Dataset', 'Trim Percent',
#        'Trim Effeciency'],
#       dtype='object')
#     Unnamed: 0                                        EC Filename  \
# 4            4  bfc_rep.seq_sim_rl_100_cov_1_1_18.corrected.fa...
# 6            7  bless_rep.seq_sim_rl_100_cov_1_1_18.corrected....
# 7            8  bfc_rep.seq_sim_rl_100_cov_2_1_18.corrected.fa...
# 11          13  lighter_rep.seq_sim_rl_100_cov_1_1_18.correcte...
# 12          14  bless_rep.seq_sim_rl_100_cov_2_1_18.corrected....
#
#       Wrapper Name  Kmer Size  Read - TP  Read - TN  Read - FN  \
# 4       run.bfc.sh         18        167        942       5979
# 6     run.bless.sh         18       4356       1336        741
# 7       run.bfc.sh         18        241       1897      12153
# 11  run.lighter.sh         18          0        946       6234
# 12    run.bless.sh         18       9198       2552       1815
#
#     Read - FN WRONG  Read - FP  Read - FP INDEL        ...          Coverage  \
# 4                 1         91                0        ...                 1
# 6                 8        693               46        ...                 1
# 7                 1         68                0        ...                 2
# 11                0          0                0        ...                 1
# 12                9        715               71        ...                 2
#
#     Length  Base Sensitivity  Base Precision  Base Gain  Base Accuracy  \
# 4     100L          0.050105        0.751832   0.033566       0.980702
# 6     100L          0.891575        0.768728   0.623345       0.922987
# 7     100L          0.026240        0.802338   0.019775       0.980356
# 11    100L          0.000000             NaN   0.000000       0.980032
# 12    100L          0.886248        0.859268   0.741097       0.936254
#
#     Dataset  Trim Percent  Trim Effeciency  total_corrections
# 4       IGH      0.000000         0.000000                955
# 6       IGH      0.072534         3.302041              14000
# 7       IGH      0.000000         0.000000                941
# 11      IGH      0.000000         0.000000                  0
# 12      IGH      0.061469         4.014226              25285
#
# [5 rows x 32 columns]

# %%
data= data[(data['Kmer Size'] ==24)]
data
# Out:
#      Unnamed: 0                                        EC Filename  \
# 184         364  bfc_rep.seq_sim_rl_100_cov_8_1_24.corrected.fa...
# 185         365  bfc_rep.seq_sim_rl_100_cov_32_1_24.corrected.f...
# 189         370  bless_rep.seq_sim_rl_100_cov_128_1_24.correcte...
# 269         452  coral_rep.seq_sim_rl_100_cov_1_1_24.corrected....
# 270         453  coral_rep.seq_sim_rl_100_cov_2_1_24.corrected....
# 275         458  coral_rep.seq_sim_rl_100_cov_64_1_24.corrected...
# 283         466  coral_rep.seq_sim_rl_100_cov_4_1_24.corrected....
# 293         476  coral_rep.seq_sim_rl_100_cov_8_1_24.corrected....
# 320         504  coral_rep.seq_sim_rl_100_cov_16_1_24.corrected...
# 365         549  coral_rep.seq_sim_rl_100_cov_32_1_24.corrected...
# 381         565  bless_rep.seq_sim_rl_100_cov_64_1_24.corrected...
# 443         627  lighter_rep.seq_sim_rl_100_cov_1_1_24.correcte...
# 445         629  lighter_rep.seq_sim_rl_100_cov_2_1_24.correcte...
# 446         630  musket_rep.seq_sim_rl_100_cov_1_1_24.corrected...
# 448         632  musket_rep.seq_sim_rl_100_cov_2_1_24.corrected...
# 455         639  lighter_rep.seq_sim_rl_100_cov_4_1_24.correcte...
# 458         642  lighter_rep.seq_sim_rl_100_cov_128_1_24.correc...
# 459         643  lighter_rep.seq_sim_rl_100_cov_64_1_24.correct...
# 460         644  musket_rep.seq_sim_rl_100_cov_64_1_24.correcte...
# 461         645  musket_rep.seq_sim_rl_100_cov_128_1_24.correct...
# 462         646  lighter_rep.seq_sim_rl_100_cov_8_1_24.correcte...
# 464         648  musket_rep.seq_sim_rl_100_cov_4_1_24.corrected...
# 477         661  musket_rep.seq_sim_rl_100_cov_8_1_24.corrected...
# 484         668  lighter_rep.seq_sim_rl_100_cov_16_1_24.correct...
# 506         690  musket_rep.seq_sim_rl_100_cov_16_1_24.correcte...
# 517         701  lighter_rep.seq_sim_rl_100_cov_32_1_24.correct...
# 543         727  musket_rep.seq_sim_rl_100_cov_32_1_24.correcte...
# 670         854  pollux_rep.seq_sim_rl_100_cov_1_1_24.corrected...
# 674         858  pollux_rep.seq_sim_rl_100_cov_2_1_24.corrected...
# 681         866  pollux_rep.seq_sim_rl_100_cov_64_1_24.correcte...
# 682         867  pollux_rep.seq_sim_rl_100_cov_4_1_24.corrected...
# 689         874  pollux_rep.seq_sim_rl_100_cov_128_1_24.correct...
# 698         884  pollux_rep.seq_sim_rl_100_cov_8_1_24.corrected...
# 717         903  pollux_rep.seq_sim_rl_100_cov_16_1_24.correcte...
# 736         922  pollux_rep.seq_sim_rl_100_cov_32_1_24.correcte...
# 859        1046  reckoner_rep.seq_sim_rl_100_cov_1_1_24.correct...
# 862        1049  sga_rep.seq_sim_rl_100_cov_1_1_24.corrected.fa...
# 863        1050  reckoner_rep.seq_sim_rl_100_cov_2_1_24.correct...
# 867        1055  sga_rep.seq_sim_rl_100_cov_2_1_24.corrected.fa...
# 868        1057  reckoner_rep.seq_sim_rl_100_cov_4_1_24.correct...
# 870        1060  sga_rep.seq_sim_rl_100_cov_4_1_24.corrected.fa...
# 871        1061  reckoner_rep.seq_sim_rl_100_cov_8_1_24.correct...
# 876        1071  sga_rep.seq_sim_rl_100_cov_8_1_24.corrected.fa...
# 878        1080  reckoner_rep.seq_sim_rl_100_cov_16_1_24.correc...
# 885        1114  sga_rep.seq_sim_rl_100_cov_16_1_24.corrected.f...
# 886        1142  reckoner_rep.seq_sim_rl_100_cov_32_1_24.correc...
# 892        1178  sga_rep.seq_sim_rl_100_cov_32_1_24.corrected.f...
# 898        1194  reckoner_rep.seq_sim_rl_100_cov_64_1_24.correc...
# 912        1323  sga_rep.seq_sim_rl_100_cov_64_1_24.corrected.f...
#
#         Wrapper Name  Kmer Size  Read - TP  Read - TN  Read - FN  \
# 184       run.bfc.sh         24          0        131        894
# 185       run.bfc.sh         24          0         88        535
# 189     run.bless.sh         24          0         65        337
# 269     run.coral.sh         24          2          0          0
# 270     run.coral.sh         24       5847       1081       1143
# 275     run.coral.sh         24          0         23        105
# 283     run.coral.sh         24       2428        462        422
# 293     run.coral.sh         24      37560       6728       7021
# 320     run.coral.sh         24      65602      14297      26728
# 365     run.coral.sh         24      99966      28348      80522
# 381     run.bless.sh         24     116163      84844     227643
# 443   run.lighter.sh         24          0        946       6234
# 445   run.lighter.sh         24          0       1900      12460
# 446    run.musket.sh         24       5065        891        524
# 448    run.musket.sh         24      10226       1740        888
# 455   run.lighter.sh         24          0       3671      24657
# 458   run.lighter.sh         24          2       4732      30880
# 459   run.lighter.sh         24        575       9088      58275
# 460    run.musket.sh         24      25113      17292      83794
# 461    run.musket.sh         24        552      10504      68397
# 462   run.lighter.sh         24          0       6493      42832
# 464    run.musket.sh         24      21256       3462       1563
# 477    run.musket.sh         24      33600       6025       4756
# 484   run.lighter.sh         24         34       3783      24631
# 506    run.musket.sh         24      19882       3823       4234
# 517   run.lighter.sh         24          0      11107      72387
# 543    run.musket.sh         24      52565      15166      39586
# 670    run.pollux.sh         24       3068        736       1568
# 674    run.pollux.sh         24       6019       1503       2909
# 681    run.pollux.sh         24       5502       1190       1569
# 682    run.pollux.sh         24       2417        717       1640
# 689    run.pollux.sh         24       3312        875       1997
# 698    run.pollux.sh         24       9347       2389       5107
# 717    run.pollux.sh         24       6960       2050       5392
# 736    run.pollux.sh         24      97527      22490      45866
# 859  run.reckoner.sh         24       4397        922       1527
# 862       run.sga.sh         24       3220        937       2818
# 863  run.reckoner.sh         24       7121       1879       4847
# 867       run.sga.sh         24       4217       1890       7733
# 868  run.reckoner.sh         24       9406       3652      13906
# 870       run.sga.sh         24       4351       3660      19089
# 871  run.reckoner.sh         24      10315       7362      34897
# 876       run.sga.sh         24       3432       7369      43211
# 878  run.reckoner.sh         24       7967      11461      62633
# 885       run.sga.sh         24       2358      14721      92395
# 886  run.reckoner.sh         24       3866      12580      74692
# 892       run.sga.sh         24       1132      15374      96825
# 898  run.reckoner.sh         24        337        648       3508
# 912       run.sga.sh         24        557      10768      69109
#
#      Read - FN WRONG  Read - FP  Read - FP INDEL        ...          Coverage  \
# 184                0          0                0        ...                 8
# 185                0          0                0        ...                32
# 189                0          1                0        ...               128
# 269                0          0                0        ...                 1
# 270                6        530              539        ...                 2
# 275                0          0                2        ...                64
# 283                3        269               70        ...                 4
# 293               38       1910             2713        ...                 8
# 320               65       3809             1425        ...                16
# 365               85       7164             7411        ...                32
# 381              282      17041              873        ...                64
# 443                0          0                0        ...                 1
# 445                0          0                0        ...                 2
# 446               37        663                0        ...                 1
# 448               86       1420                0        ...                 2
# 455                0          0                0        ...                 4
# 458               27        154                0        ...               128
# 459               51        579                0        ...                64
# 460              361       5654                0        ...                64
# 461               88        286                0        ...               128
# 462                0          0                0        ...                 8
# 464              165       1882                0        ...                 4
# 477              238       2369                0        ...                 8
# 484               19        295                0        ...                16
# 506              185       1639                0        ...                16
# 517                0          0                0        ...                32
# 543              434       7005                0        ...                32
# 670               39       1222              505        ...                 1
# 674               84       2535             1066        ...                 2
# 681               67        200              111        ...                64
# 682               36       1161              550        ...                 4
# 689               35        508              447        ...               128
# 698              104       3818             1709        ...                 8
# 717               71       3672             1540        ...                16
# 736             1073      38491            11618        ...                32
# 859               39        231               64        ...                 1
# 862                9        193                3        ...                 1
# 863               65        392               56        ...                 2
# 867               22        497                1        ...                 2
# 868              104       1162               98        ...                 4
# 870               33       1187                8        ...                 4
# 871              190       2904              302        ...                 8
# 876               65       1876               17        ...                 8
# 878              294       3609              501        ...                16
# 885              100       2326               26        ...                16
# 886              295       2654              526        ...                32
# 892               67       1593               21        ...                32
# 898               21        358               43        ...                64
# 912               32        967               12        ...                64
#
#      Length  Base Sensitivity  Base Precision  Base Gain  Base Accuracy  \
# 184    100L          0.000000             NaN   0.000000       0.980166
# 185    100L          0.000000             NaN   0.000000       0.980770
# 189    100L          0.110429        0.986301   0.108896       0.917164
# 269    100L          1.000000        1.000000   1.000000       1.000000
# 270    100L          0.833077        0.892155   0.732373       0.994649
# 275    100L          0.556818        0.986577   0.549242       0.990848
# 283    100L          0.836535        0.904019   0.747718       0.994886
# 293    100L          0.834456        0.941853   0.782939       0.995629
# 320    100L          0.777130        0.954486   0.740073       0.994778
# 365    100L          0.725936        0.937961   0.677921       0.993538
# 381    100L          0.480458        0.868726   0.407855       0.889661
# 443    100L          0.000000             NaN   0.000000       0.980032
# 445    100L          0.000000             NaN   0.000000       0.979960
# 446    100L          0.918926        0.902857   0.820055       0.996331
# 448    100L          0.924796        0.893718   0.814817       0.996212
# 455    100L          0.000000             NaN   0.000000       0.979959
# 458    100L          0.113811        0.973798   0.110749       0.982225
# 459    100L          0.241289        0.971294   0.234158       0.984717
# 460    100L          0.407302        0.935520   0.379229       0.987537
# 461    100L          0.106026        0.976552   0.103480       0.981989
# 462    100L          0.000000             NaN   0.000000       0.979881
# 464    100L          0.944376        0.931147   0.874544       0.997408
# 477    100L          0.922900        0.946927   0.871173       0.997341
# 484    100L          0.022125        0.795779   0.016447       0.980179
# 506    100L          0.888397        0.939558   0.831247       0.996518
# 517    100L          0.000000             NaN   0.000000       0.979983
# 543    100L          0.723160        0.942109   0.678723       0.993519
# 670    100L          0.714967        0.715477   0.430647       0.988533
# 674    100L          0.724821        0.689226   0.397997       0.987827
# 681    100L          0.831732        0.955910   0.793370       0.995742
# 682    100L          0.676246        0.646223   0.306033       0.985881
# 689    100L          0.685285        0.756878   0.465160       0.988949
# 698    100L          0.716037        0.668274   0.360602       0.986985
# 717    100L          0.663116        0.575357   0.173703       0.983338
# 736    100L          0.757069        0.711086   0.449471       0.988840
# 859    100L          0.766463        0.818953   0.597020       0.991706
# 862    100L          0.626581        0.950700   0.594088       0.991872
# 863    100L          0.636040        0.860733   0.533129       0.990494
# 867    100L          0.481275        0.940360   0.450752       0.988976
# 868    100L          0.477369        0.800706   0.358553       0.987031
# 870    100L          0.326870        0.890812   0.286806       0.985694
# 871    100L          0.349517        0.704495   0.202909       0.983861
# 876    100L          0.209011        0.871010   0.178058       0.983484
# 878    100L          0.271852        0.657673   0.130350       0.982438
# 885    100L          0.144332        0.876389   0.123975       0.982442
# 886    100L          0.237991        0.662129   0.116549       0.982164
# 892    100L          0.121630        0.890826   0.106724       0.982106
# 898    100L          0.253242        0.511762   0.011641       0.980024
# 912    100L          0.108012        0.892380   0.094986       0.981904
#
#      Dataset  Trim Percent  Trim Effeciency  total_corrections
# 184      IGH  0.000000e+00         0.000000                  0
# 185      IGH  0.000000e+00         0.000000                  0
# 189      IGH  7.124069e-02         4.319053                 73
# 269      IGH  0.000000e+00         0.000000                  4
# 270      IGH  1.092745e-05        10.000000              16420
# 275      IGH  0.000000e+00         0.000000                147
# 283      IGH  1.915358e-05        42.857143               6718
# 293      IGH  6.607421e-06        27.027027              96741
# 320      IGH  8.575991e-06        35.416667             180918
# 365      IGH  7.872040e-06        28.977273             338057
# 381      IGH  1.047392e-01         4.039229             381487
# 443      IGH  0.000000e+00         0.000000                  0
# 445      IGH  0.000000e+00         0.000000                  0
# 446      IGH  0.000000e+00         0.000000              14525
# 448      IGH  0.000000e+00         0.000000              29638
# 455      IGH  0.000000e+00         0.000000                  0
# 458      IGH  0.000000e+00         0.000000               8358
# 459      IGH  0.000000e+00         0.000000              33965
# 460      IGH  0.000000e+00         0.000000             115152
# 461      IGH  0.000000e+00         0.000000              17400
# 462      IGH  0.000000e+00         0.000000                  0
# 464      IGH  0.000000e+00         0.000000              57325
# 477      IGH  0.000000e+00         0.000000              91723
# 484      IGH  0.000000e+00         0.000000               1611
# 506      IGH  0.000000e+00         0.000000              56418
# 517      IGH  0.000000e+00         0.000000                  0
# 543      IGH  0.000000e+00         0.000000             175829
# 670      IGH  9.803304e-06        14.285714              13194
# 674      IGH  1.557838e-05         0.000000              27615
# 681      IGH  1.620372e-05         7.142857              14667
# 682      IGH  1.532837e-05         0.000000              12510
# 689      IGH  2.355319e-04         1.183432              11988
# 698      IGH  1.823718e-05         0.000000              44870
# 717      IGH  1.625042e-05         3.125000              41900
# 736      IGH  1.948211e-05         5.910165             437194
# 859      IGH  1.753939e-04         3.968254              12680
# 862      IGH  1.392744e-06         0.000000               9419
# 863      IGH  1.093007e-04         2.547771              20523
# 867      IGH  2.089132e-06         0.000000              14702
# 868      IGH  8.823107e-05         2.400000              32620
# 870      IGH  3.530060e-06         0.000000              20783
# 871      IGH  1.182380e-04         2.265861              52450
# 876      IGH  1.965325e-06         0.000000              26875
# 878      IGH  1.520201e-04         2.661597              65281
# 885      IGH  2.233607e-06         4.000000              36804
# 886      IGH  1.595309e-04         1.788079              61476
# 892      IGH  3.303988e-06         0.000000              31360
# 898      IGH  1.972210e-04         2.061856               4280
# 912      IGH  6.139099e-07         0.000000              19669
#
# [49 rows x 32 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
g=sns.set_style("white")
g=sns.set_context("talk")

g = sns.catplot(x="Coverage", y="Trim Percent", kind="point",data=data,hue='Tool')
g.set(xlabel='Coverage', ylabel='Percentage of trimmed bases (%)')
g=sns.despine()
#plt.show(g)
plt.savefig("Trim_Percent.png", bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
g=sns.set_style("white")
g=sns.set_context("talk")

g = sns.catplot(x="Coverage", y="Trim Effeciency", kind="point",data=data,hue='Tool')
g.set(xlabel='Coverage', ylabel='Trim effeciency (%)')
g=sns.despine()
#plt.show(g)
plt.savefig("Trim_Percent.png", bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
g=sns.set_style("white")
g=sns.set_context("talk")
g = sns.catplot(x="Coverage", y="total_corrections", kind="point",data=data,hue='Tool')
, hue='Tool')
g.set(xlabel='Coverage', ylabel='Total corrections')
g=sns.despine()
#plt.show(g)
plt.savefig("total_corrections_vs_cov.png", bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
g=sns.set_style("white")
g=sns.set_context("talk")
g = sns.catplot(x="Coverage", y="Base - TP", kind="point",data=data,hue='Tool')
, hue='Tool')
g.set(xlabel='Coverage', ylabel='TP')
g=sns.despine()
#plt.show(g)
plt.savefig("TP_vs_cov.png", bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
g=sns.set_style("white")
g=sns.set_context("talk")
g = sns.catplot(x="Coverage", y="Base - FP", kind="point",data=data,hue='Tool')
, hue='Tool')
g.set(xlabel='Coverage', ylabel='FP')
g=sns.despine()
#plt.show(g)
plt.savefig("FP_vs_cov.png", bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
g=sns.set_style("white")
g=sns.set_context("talk")
g = sns.catplot(x="Coverage", y="Base - FN", kind="point",data=data,hue='Tool')
, hue='Tool')
g.set(xlabel='Coverage', ylabel='FN')
g=sns.despine()
#plt.show(g)
plt.savefig("FN_vs_cov.png", bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
g=sns.set_style("white")
g=sns.set_context("talk")
g = sns.catplot(x="Coverage", y="Base Gain", kind="point",data=data,hue='Tool')
, hue='Tool')
g.set(xlabel='Coverage', ylabel='Gain')
g=sns.despine()
#plt.show(g)
plt.savefig("gain_vs_cov_IGH.png", bbox_inches='tight')

# %%
result = data.pivot(index='Tool', columns='Coverage', values='Base Gain')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
g=sns.set_style("white")
g=sns.set_context("talk")
g=sns.heatmap(result, fmt="g", cmap='coolwarm',center=0,linewidths=.5)
plt.savefig("heatmap_gain_vs_cov_IGH.png", bbox_inches='tight')

# %%
result_PPV = data.pivot(index='Tool', columns='Coverage', values='Base Precision')

import matplotlib.pyplot as plt
import seaborn as sns
g=sns.set_style("white")
g=sns.set_context("talk")
g=sns.heatmap(result_PPV, fmt="g", cmap='coolwarm',center=0,linewidths=.5)
plt.savefig("heatmap_ppv_vs_cov_IGH.png", bbox_inches='tight')

# %%
result_Sensitivity = data.pivot(index='Tool', columns='Coverage', values='Base Sensitivity')

import matplotlib.pyplot as plt
import seaborn as sns
g=sns.set_style("white")
g=sns.set_context("talk")
g=sns.heatmap(result_Sensitivity, fmt="g", cmap='coolwarm',center=0,linewidths=.5)
plt.savefig("heatmap_sensitivity_vs_cov_IGH.png", bbox_inches='tight')

# %%
data['TP_100K']=data['Base - TP']/1000
data['FP_100K']=data['Base - FP']/1000
data['FN_100K']=data['Base - FN']/1000

markers = ['o', 's', 'p', 'x', '^', '+', '*', '<', 'D', 'h', '>']
import matplotlib.pyplot as plt
import seaborn as sns
g=sns.set_style("white")
g=sns.set_context("talk")
g=sns.lmplot(data=data[(data['Coverage'] ==32)], x='TP_100K', y='FN_100K', hue='Tool',fit_reg=False)
g.set(xlabel='TP', ylabel='FP')
g=sns.despine()
#plt.show(g)
plt.savefig("TP_vs_FP_IGH.png", bbox_inches='tight')

# %%
data['TP_100K']=data['Base - TP']/1000
data['FP_100K']=data['Base - FP']/1000
data['FN_100K']=data['Base - FN']/1000

markers = ['o', 's', 'p', 'x', '^', '+', '*', '<', 'D', 'h', '>']
import matplotlib.pyplot as plt
import seaborn as sns
g=sns.set_style("white")
g=sns.set_context("talk")
g=sns.lmplot(data=data[(data['Coverage'] ==32)], x='TP_100K', y='FN_100K', hue='Tool',fit_reg=False)
g.set(xlabel='TP', ylabel='FN')
g=sns.despine()
#plt.show(g)
plt.savefig("TP_vs_FN_IGH.png", bbox_inches='tight')

# %%
data['TP_100K']=data['Base - TP']/1000
data['FP_100K']=data['Base - FP']/1000
data['FN_100K']=data['Base - FN']/1000

markers = ['o', 's', 'p', 'x', '^', '+', '*', '<', 'D', 'h', '>']
import matplotlib.pyplot as plt
import seaborn as sns
g=sns.set_style("white")
g=sns.set_context("talk")
g=sns.lmplot(data=data[(data['Coverage'] ==32)], x='Base Precision', y='Base Sensitivity', hue='Tool',fit_reg=False)
g.set(xlabel='Precision', ylabel='Sensitivity')
g=sns.despine()
#plt.show(g)
plt.savefig("Precision_vs_Sensitivity_IGH.png", bbox_inches='tight')
