# %%
from __future__ import division
import pylab as pl
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
import math
import seaborn as sns

# %%
data = pd.read_csv('./data/tra_from_master.csv')
data = data[(data['Length'] =='100L')]
data.tail()
# Out:
#      Unnamed: 0                                        EC Filename  \
# 550         940  sga_TRA.rep.seq_sim_rl_100_cov_128_1_18.correc...
# 552         942  reckoner_TRA.rep.seq_sim_rl_100_cov_128_1_23.c...
# 553         943  sga_TRA.rep.seq_sim_rl_100_cov_128_1_20.correc...
# 554         944  reckoner_TRA.rep.seq_sim_rl_100_cov_128_1_24.c...
# 555         945  reckoner_TRA.rep.seq_sim_rl_100_cov_128_1_19.c...
#
#         Wrapper Name  Kmer Size  Read - TP  Read - TN  Read - FN  \
# 550       run.sga.sh         18        925     102537     668429
# 552  run.reckoner.sh         23       6604     102537     658695
# 553       run.sga.sh         20       1112     102537     668145
# 554  run.reckoner.sh         24       6988     102537     658016
# 555  run.reckoner.sh         19       5159     102537     660462
#
#      Read - FN WRONG  Read - FP  Read - FP INDEL       ...             Tool  \
# 550               44       1595               40       ...              Sga
# 552              584       3219             1931       ...         Reckoner
# 553               52       1664               60       ...              Sga
# 554              615       3327             2087       ...         Reckoner
# 555              516       3297             1599       ...         Reckoner
#
#      Coverage  Length  Base Sensitivity  Base Precision  Base Gain  \
# 550       128    100L          0.046365        0.943050   0.043565
# 552       128    100L          0.171702        0.801470   0.129170
# 553       128    100L          0.057185        0.948387   0.054073
# 554       128    100L          0.178758        0.797036   0.133237
# 555       128    100L          0.143664        0.789082   0.105263
#
#      Base Accuracy  Dataset  Trim Percent  Trim Effeciency
# 550       0.980864      TRA  4.653742e-07         0.028571
# 552       0.982539      TRA  4.058435e-05         0.031876
# 553       0.981074      TRA  5.817174e-07         0.022727
# 554       0.982615      TRA  4.574079e-05         0.028181
# 555       0.982064      TRA  3.745744e-05         0.028024
#
# [5 rows x 31 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
g=sns.set_style("white")
g=sns.set_context("talk")
g = sns.catplot(x="Kmer Size", y="Base Gain", kind="point",data = data[(data['Coverage'] ==4)]
, hue='Tool')
g.set(xlabel='Kmer size', ylabel='Gain')
g=sns.despine()
#plt.show(g)
plt.savefig("gain_cov4_TCRA.png", bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
g=sns.set_style("white")
g=sns.set_context("talk")
g = sns.catplot(x="Kmer Size", y="Base Gain", kind="point",data = data[(data['Coverage'] ==32)]
, hue='Tool')
g.set(xlabel='Kmer size', ylabel='Gain')
g=sns.despine()
#plt.show(g)
plt.savefig("gain_cov4_TCRA.png", bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
g=sns.set_style("white")
g=sns.set_context("talk")
g = sns.catplot(x="Kmer Size", y="Base Gain", kind="point",data = data[(data['Coverage'] ==128)]
, hue='Tool')
g.set(xlabel='Kmer size', ylabel='Gain')
g=sns.despine()
#plt.show(g)
plt.savefig("gain_cov128_TCRA.png", bbox_inches='tight')
